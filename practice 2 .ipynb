# %%
A=int(input("Enter the number A:"))
B=int(input("Enter the number B:"))
C=int(input("Enter the number C:"))
if A>B and A>C:
    print(A,"is greater")
elif B>A and B>C:
    print(B,"is greater")
else:
    print(C,"is greater")
# Out:
# Enter the number A: 2
# Enter the number B: 3
# Enter the number C: 4
# 4 is greater

# %%
A=int(input("Enter the number A:"))
B=int(input("Enter the number B:"))
C=int(input("Enter the number C:"))
D=int(input("Enter the number D:"))
if A<B and A<C and A<D:
    print(A,"is smaller")
elif B<A and B<C and B<D:
    print(B,"is smaller")
elif C<A and C<B and C<D:
    print(C,"is smaller")
else:
    print(D,"is smaller")
# Out:
# Enter the number A: 2
# Enter the number B: 3
# Enter the number C: 5
# Enter the number D: 4
# 2 is smaller

# %%
A=int(input("Enter the number A:"))
if A>0:
    print(A, "is positive")
elif A<0:
    print(A,"is negative")
else:
    print(0,"is neither postive or negative")
# Out:
# Enter the number A: -6
# -6 is negative

# %%
import math
num=int(input("enter the number"))
sqrt_num=math.sqrt(num)
if sqrt_num**2==num:
    print("yes")
else:
    print("no")
# Out:
# enter the number 25
# yes

# %%
a=["a","e","i","o","u"]
b=input("Enter the word:")
if b in a:
    print("vowel")
elif b.isalpha():
    print("constant")
else:
    print("not a alhabate")
# Out:
# Enter the word: x
# constant

# %%
x=int(input("x="))
y=int(input("y="))
if x>0 and y>0:
    print("1st  quadrant number")
elif x<0 and y>0:
    print("2nd  quadrant number")
elif x<0 and y<0:
    print("3rd  quadrant number")
elif x>0 and y<0:
    print("4th  quadrant number")
else:
    print("orgin")
# Out:
# x= 2
# y= 4
# 1st  quadrant number

# %%
x=int(input("x="))
y=int(input("y="))
if x>0 and y>0:
    print("1st  quadrant number")
elif x<0 and y>0:
    print("2nd  quadrant number")
elif x<0 and y<0:
    print("3rd  quadrant number")
elif x>0 and y<0:
    print("4th  quadrant number")
else:
    print("orgin")

# %%
days = 373

years = days // 365
weeks = (days % 365) // 7
days = (days % 365) % 7

print(years, weeks, days)
# Out:
# 1 1 1

# %%
weight = 50
height = 1.6

bmi = weight / (height ** 2)

print(round(bmi, 2))
# Out:
# 19.53

# %%
num = 456
reversed_num = int(str(num)[::-1])

print(reversed_num)
# Out:
# 654
